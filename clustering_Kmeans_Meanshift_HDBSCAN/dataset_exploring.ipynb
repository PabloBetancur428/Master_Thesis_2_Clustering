# %% [markdown]
# # Extracted features analysis

# %%
# %% [markdown]
# # Radiomic Features Data Debugging Pipeline
#
# In this notebook, we'll:
#
# 1. Load the dataset.
# 2. Examine basic information and summary statistics.
# 3. Check for missing values, infinite values, and constant (or near-constant) columns.
# 4. Identify rows with problematic values.
# 5. Visualize the distributions of each numeric column (to spot potential outliers).
#
# This will help us pinpoint issues before applying any standardization or clustering steps.

# %% 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Change this path to point to your dataset
file_path = "/home/jbetancur/Desktop/codes/clustering/feature_extraction/output/aggregated_lesion_features.csv" 

# Load the dataset
df = pd.read_csv(file_path)
print("Dataset loaded successfully!")
print("Dataset shape:", df.shape)

# %% [markdown]
# ## Basic Information and Summary Statistics

# %%
# Print basic info and the first few rows of the dataset
print("\n--- DataFrame Info ---")
print(df.info())
print("\n--- First 5 Rows ---")
print(df.head())

print("\n--- Descriptive Statistics for Numeric Columns ---")
print(df.describe())

# %% [markdown]
# ## Missing and Infinite Values Check

# %%
# Count missing values per column
missing_counts = df.isnull().sum()
print("\n--- Missing Values per Column ---")
print(missing_counts[missing_counts > 0])


# %% [markdown]
# ## Check for Constant or Near-Constant Columns
#
# These columns have zero (or almost zero) standard deviation, which might interfere with scaling.

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns
print("\n--- Columns with Zero or Near-Zero Standard Deviation ---")
for col in numeric_cols:
    std = df[col].std()
    if std == 0 or np.isnan(std):
        print(f"{col}: std = {std}")
        
# Alternatively, if you want to flag columns with extremely low variation (e.g., std < a small threshold)
low_variation_cols = [col for col in numeric_cols if 0 < df[col].std() < 1e-8]
if low_variation_cols:
    print("\nColumns with extremely low variation (std < 1e-8):")
    print(low_variation_cols)

# %% [markdown]
# ## Unique Value Counts per Column
#
# Sometimes, columns with too few unique values may indicate categorical or constant data that need special handling.

# %%
print("\n--- Unique Value Counts per Column ---")
for col in df.columns:
    unique_count = df[col].nunique()
    print(f"{col}: {unique_count} unique values")

# %% [markdown]
# ## Identify Rows with Problematic Values
#
# Let's locate any rows that contain missing or infinite values.

# %%
# Identify rows with any NaN or infinite values
problematic_rows = df[df.isnull().any(axis=1)]
print("\n--- Rows with Missing or Infinite Values ---")
print(problematic_rows)

# %% [markdown]
# ## Visualize Distributions for Each Numeric Column
#
# Histograms and boxplots help to spot outliers or weird distributions that could affect standardization.

# %%
for col in numeric_cols:
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    sns.histplot(df[col].dropna(), kde=True, ax=axes[0])
    axes[0].set_title(f"Distribution of {col}")
    sns.boxplot(x=df[col].dropna(), ax=axes[1])
    axes[1].set_title(f"Boxplot of {col}")
    plt.tight_layout()
    plt.show()
# Out:
# Dataset loaded successfully!
# Dataset shape: (3766, 87)
#
# --- DataFrame Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3766 entries, 0 to 3765
# Data columns (total 87 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   label_id                            3766 non-null   int64
#  1   num_voxels                          3766 non-null   int64
#  2   volume_physical                     3766 non-null   float64
#  3   T1_mean                             3766 non-null   float64
#  4   T1_std                              3766 non-null   float64
#  5   T2_mean                             3766 non-null   float64
#  6   T2_std                              3766 non-null   float64
#  7   QSM_mean                            3766 non-null   float64
#  8   QSM_std                             3766 non-null   float64
#  9   T1_min                              3766 non-null   float64
#  10  T1_max                              3766 non-null   float64
#  11  T1_range                            3766 non-null   float64
#  12  T1_median                           3766 non-null   float64
#  13  T1_percentile_10                    3766 non-null   float64
#  14  T1_percentile_90                    3766 non-null   float64
#  15  T1_skewness                         3763 non-null   float64
#  16  T1_kurtosis                         3763 non-null   float64
#  17  T1_energy                           3766 non-null   float64
#  18  T1_entropy                          3766 non-null   float64
#  19  T2_min                              3766 non-null   float64
#  20  T2_max                              3766 non-null   float64
#  21  T2_range                            3766 non-null   float64
#  22  T2_median                           3766 non-null   float64
#  23  T2_percentile_10                    3766 non-null   float64
#  24  T2_percentile_90                    3766 non-null   float64
#  25  T2_skewness                         3763 non-null   float64
#  26  T2_kurtosis                         3763 non-null   float64
#  27  T2_energy                           3766 non-null   float64
#  28  T2_entropy                          3766 non-null   float64
#  29  QSM_min                             3766 non-null   float64
#  30  QSM_max                             3766 non-null   float64
#  31  QSM_range                           3766 non-null   float64
#  32  QSM_median                          3766 non-null   float64
#  33  QSM_percentile_10                   3766 non-null   float64
#  34  QSM_percentile_90                   3766 non-null   float64
#  35  QSM_skewness                        3756 non-null   float64
#  36  QSM_kurtosis                        3756 non-null   float64
#  37  QSM_energy                          3766 non-null   float64
#  38  QSM_entropy                         3766 non-null   float64
#  39  T1_glcm_contrast                    3766 non-null   float64
#  40  T1_glcm_dissimilarity               3766 non-null   float64
#  41  T1_glcm_homogeneity                 3766 non-null   float64
#  42  T1_glcm_energy                      3766 non-null   float64
#  43  T1_glcm_correlation                 3766 non-null   float64
#  44  T1_glcm_asm                         3766 non-null   float64
#  45  T1_glcm_entropy                     3766 non-null   float64
#  46  T1_glcm_max_probability             3766 non-null   float64
#  47  T1_glcm_cluster_shade               3766 non-null   float64
#  48  T1_glcm_cluster_prominence          3766 non-null   float64
#  49  T1_glrlm_mean_run                   3766 non-null   float64
#  50  T1_glrlm_short_run_emphasis         3766 non-null   float64
#  51  T1_glrlm_long_run_emphasis          3766 non-null   float64
#  52  T1_glrlm_gray_level_nonuniformity   3766 non-null   float64
#  53  T1_glrlm_run_length_nonuniformity   3766 non-null   float64
#  54  T2_glcm_contrast                    3766 non-null   float64
#  55  T2_glcm_dissimilarity               3766 non-null   float64
#  56  T2_glcm_homogeneity                 3766 non-null   float64
#  57  T2_glcm_energy                      3766 non-null   float64
#  58  T2_glcm_correlation                 3766 non-null   float64
#  59  T2_glcm_asm                         3766 non-null   float64
#  60  T2_glcm_entropy                     3766 non-null   float64
#  61  T2_glcm_max_probability             3766 non-null   float64
#  62  T2_glcm_cluster_shade               3766 non-null   float64
#  63  T2_glcm_cluster_prominence          3766 non-null   float64
#  64  T2_glrlm_mean_run                   3766 non-null   float64
#  65  T2_glrlm_short_run_emphasis         3766 non-null   float64
#  66  T2_glrlm_long_run_emphasis          3766 non-null   float64
#  67  T2_glrlm_gray_level_nonuniformity   3766 non-null   float64
#  68  T2_glrlm_run_length_nonuniformity   3766 non-null   float64
#  69  QSM_glcm_contrast                   3766 non-null   float64
#  70  QSM_glcm_dissimilarity              3766 non-null   float64
#  71  QSM_glcm_homogeneity                3766 non-null   float64
#  72  QSM_glcm_energy                     3766 non-null   float64
#  73  QSM_glcm_correlation                3766 non-null   float64
#  74  QSM_glcm_asm                        3766 non-null   float64
#  75  QSM_glcm_entropy                    3766 non-null   float64
#  76  QSM_glcm_max_probability            3766 non-null   float64
#  77  QSM_glcm_cluster_shade              3766 non-null   float64
#  78  QSM_glcm_cluster_prominence         3766 non-null   float64
#  79  QSM_glrlm_mean_run                  3766 non-null   float64
#  80  QSM_glrlm_short_run_emphasis        3766 non-null   float64
#  81  QSM_glrlm_long_run_emphasis         3766 non-null   float64
#  82  QSM_glrlm_gray_level_nonuniformity  3766 non-null   float64
#  83  QSM_glrlm_run_length_nonuniformity  3766 non-null   float64
#  84  PatientID                           3766 non-null   int64
#  85  FolderType                          3766 non-null   object
#  86  YearFolder                          3766 non-null   object
# dtypes: float64(82), int64(3), object(2)
# memory usage: 2.5+ MB
# None
#
# --- First 5 Rows ---
#    label_id  num_voxels  volume_physical     T1_mean     T1_std     T2_mean  \
# 0         1          17        16.999091  318.294910  37.783661  127.976084
# 1         2           2         1.999893  282.835464   8.481552  137.095116
# 2         3          12        11.999358  305.645069  33.002008  137.730356
# 3         4          45        44.997593  325.160775  46.772466  139.753928
# 4         5           4         3.999786  323.598480  10.150990  150.210346
#
#       T2_std  QSM_mean   QSM_std      T1_min  ...  QSM_glcm_cluster_shade  \
# 0  14.840231 -0.031915  0.031461  218.262863  ...           -3.307857e+05
# 1   1.212791 -0.021606  0.006582  274.353912  ...            1.748817e+06
# 2   9.990716 -0.020085  0.018463  246.728165  ...           -1.103862e+05
# 3  11.166565 -0.011598  0.023354  280.512848  ...            3.525992e+03
# 4   2.862079 -0.006987  0.009608  311.853424  ...            0.000000e+00
#
#    QSM_glcm_cluster_prominence  QSM_glrlm_mean_run  \
# 0                 4.761321e+08                 1.0
# 1                 3.344612e+08                 1.0
# 2                 3.873408e+08                 1.0
# 3                 1.312424e+08                 1.0
# 4                 2.181671e+08                 1.0
#
#    QSM_glrlm_short_run_emphasis  QSM_glrlm_long_run_emphasis  \
# 0                           1.0                          1.0
# 1                           1.0                          1.0
# 2                           1.0                          1.0
# 3                           1.0                          1.0
# 4                           1.0                          1.0
#
#    QSM_glrlm_gray_level_nonuniformity  QSM_glrlm_run_length_nonuniformity  \
# 0                            1.000000                                 9.0
# 1                            1.000000                                 2.0
# 2                            1.000000                                 6.0
# 3                            1.481481                                54.0
# 4                            1.000000                                 4.0
#
#    PatientID  FolderType  YearFolder
# 0   14109676    baseline        2022
# 1   14109676    baseline        2022
# 2   14109676    baseline        2022
# 3   14109676    baseline        2022
# 4   14109676    baseline        2022
#
# [5 rows x 87 columns]
#
# --- Descriptive Statistics for Numeric Columns ---
#           label_id     num_voxels  volume_physical      T1_mean       T1_std  \
# count  3766.000000    3766.000000      3766.000000  3766.000000  3766.000000
# mean     31.000266     261.349708       261.502029   314.020826    34.863713
# std      38.925410    6648.263015      6652.953415    61.369532    22.531169
# min       1.000000       1.000000         0.999983    40.215339     0.000000
# 25%       9.000000       4.000000         4.002844   272.792168    16.919561
# 50%      19.000000      16.000000        16.003643   313.873703    30.730707
# 75%      36.000000      67.000000        66.997365   354.917842    49.219643
# max     255.000000  398789.000000    399072.574196   592.001767   129.931019
#
#            T2_mean       T2_std     QSM_mean      QSM_std       T1_min  ...  \
# count  3766.000000  3766.000000  3766.000000  3766.000000  3766.000000  ...
# mean    367.823087    34.308070    -0.007523     0.027366   243.096711  ...
# std     264.676368    38.548980     0.042484     0.037348    77.794817  ...
# min       3.715278     0.000000    -0.920707     0.000000     7.802958  ...
# 25%     137.794133     8.745618    -0.025188     0.013828   193.264965  ...
# 50%     164.234251    18.491451    -0.006819     0.021522   250.312164  ...
# 75%     650.439583    44.824436     0.010620     0.032466   297.247429  ...
# max     930.696679   232.023514     0.359496     1.359853   566.608154  ...
#
#        QSM_glcm_entropy  QSM_glcm_max_probability  QSM_glcm_cluster_shade  \
# count      3.766000e+03               3766.000000            3.766000e+03
# mean       3.195047e+00                  0.059988            4.546106e+05
# std        1.772430e+00                  0.060524            1.035930e+06
# min       -1.000000e-10                  0.000000           -1.644805e+06
# 25%        2.426015e+00                  0.015561           -6.400673e+03
# 50%        3.235251e+00                  0.041667            7.150827e+04
# 75%        4.507575e+00                  0.125000            5.481594e+05
# max        8.349058e+00                  1.000000            9.330601e+06
#
#        QSM_glcm_cluster_prominence  QSM_glrlm_mean_run  \
# count                 3.766000e+03         3766.000000
# mean                  3.558620e+08            1.008335
# std                   2.803475e+08            0.118093
# min                   0.000000e+00            1.000000
# 25%                   2.356077e+08            1.000000
# 50%                   3.221397e+08            1.000000
# 75%                   3.779316e+08            1.000000
# max                   3.674304e+09            5.000000
#
#        QSM_glrlm_short_run_emphasis  QSM_glrlm_long_run_emphasis  \
# count                   3766.000000                  3766.000000
# mean                       0.995713                     1.036950
# std                        0.040053                     0.657072
# min                        0.040000                     1.000000
# 25%                        1.000000                     1.000000
# 50%                        1.000000                     1.000000
# 75%                        1.000000                     1.000000
# max                        1.000000                    25.000000
#
#        QSM_glrlm_gray_level_nonuniformity  QSM_glrlm_run_length_nonuniformity  \
# count                         3766.000000                         3766.000000
# mean                             1.270835                           23.903044
# std                              8.164033                          155.251882
# min                              1.000000                            1.000000
# 25%                              1.000000                            4.000000
# 50%                              1.000000                            7.500000
# 75%                              1.081250                           18.856228
# max                            494.620036                         8617.306955
#
#           PatientID
# count  3.766000e+03
# mean   1.333282e+07
# std    5.729070e+06
# min    1.366460e+05
# 25%    1.084421e+07
# 50%    1.315708e+07
# 75%    1.803120e+07
# max    2.107585e+07
#
# [8 rows x 85 columns]
#
# --- Missing Values per Column ---
# T1_skewness      3
# T1_kurtosis      3
# T2_skewness      3
# T2_kurtosis      3
# QSM_skewness    10
# QSM_kurtosis    10
# dtype: int64
#
# --- Columns with Zero or Near-Zero Standard Deviation ---
#
# --- Unique Value Counts per Column ---
# label_id: 255 unique values
# num_voxels: 526 unique values
# volume_physical: 2380 unique values
# T1_mean: 3766 unique values
# T1_std: 3764 unique values
# T2_mean: 3766 unique values
# T2_std: 3764 unique values
# QSM_mean: 3760 unique values
# QSM_std: 3757 unique values
# T1_min: 3765 unique values
# T1_max: 3764 unique values
# T1_range: 3764 unique values
# T1_median: 3766 unique values
# T1_percentile_10: 3766 unique values
# T1_percentile_90: 3766 unique values
# T1_skewness: 3470 unique values
# T1_kurtosis: 3440 unique values
# T1_energy: 3766 unique values
# T1_entropy: 3764 unique values
# T2_min: 3763 unique values
# T2_max: 3765 unique values
# T2_range: 3764 unique values
# T2_median: 3766 unique values
# T2_percentile_10: 3766 unique values
# T2_percentile_90: 3766 unique values
# T2_skewness: 3470 unique values
# T2_kurtosis: 3441 unique values
# T2_energy: 3766 unique values
# T2_entropy: 3764 unique values
# QSM_min: 3755 unique values
# QSM_max: 3759 unique values
# QSM_range: 3757 unique values
# QSM_median: 3757 unique values
# QSM_percentile_10: 3756 unique values
# QSM_percentile_90: 3758 unique values
# QSM_skewness: 3464 unique values
# QSM_kurtosis: 3411 unique values
# QSM_energy: 3760 unique values
# QSM_entropy: 3757 unique values
# T1_glcm_contrast: 3162 unique values
# T1_glcm_dissimilarity: 2775 unique values
# T1_glcm_homogeneity: 3167 unique values
# T1_glcm_energy: 1566 unique values
# T1_glcm_correlation: 3167 unique values
# T1_glcm_asm: 1489 unique values
# T1_glcm_entropy: 1659 unique values
# T1_glcm_max_probability: 1120 unique values
# T1_glcm_cluster_shade: 2545 unique values
# T1_glcm_cluster_prominence: 3169 unique values
# T1_glrlm_mean_run: 681 unique values
# T1_glrlm_short_run_emphasis: 680 unique values
# T1_glrlm_long_run_emphasis: 682 unique values
# T1_glrlm_gray_level_nonuniformity: 946 unique values
# T1_glrlm_run_length_nonuniformity: 1111 unique values
# T2_glcm_contrast: 3163 unique values
# T2_glcm_dissimilarity: 2790 unique values
# T2_glcm_homogeneity: 3168 unique values
# T2_glcm_energy: 1556 unique values
# T2_glcm_correlation: 3166 unique values
# T2_glcm_asm: 1485 unique values
# T2_glcm_entropy: 1643 unique values
# T2_glcm_max_probability: 1123 unique values
# T2_glcm_cluster_shade: 2545 unique values
# T2_glcm_cluster_prominence: 3169 unique values
# T2_glrlm_mean_run: 671 unique values
# T2_glrlm_short_run_emphasis: 674 unique values
# T2_glrlm_long_run_emphasis: 677 unique values
# T2_glrlm_gray_level_nonuniformity: 952 unique values
# T2_glrlm_run_length_nonuniformity: 1087 unique values
# QSM_glcm_contrast: 3163 unique values
# QSM_glcm_dissimilarity: 2786 unique values
# QSM_glcm_homogeneity: 3169 unique values
# QSM_glcm_energy: 1534 unique values
# QSM_glcm_correlation: 3167 unique values
# QSM_glcm_asm: 1466 unique values
# QSM_glcm_entropy: 1626 unique values
# QSM_glcm_max_probability: 1116 unique values
# QSM_glcm_cluster_shade: 2542 unique values
# QSM_glcm_cluster_prominence: 3167 unique values
# QSM_glrlm_mean_run: 627 unique values
# QSM_glrlm_short_run_emphasis: 629 unique values
# QSM_glrlm_long_run_emphasis: 631 unique values
# QSM_glrlm_gray_level_nonuniformity: 959 unique values
# QSM_glrlm_run_length_nonuniformity: 1059 unique values
# PatientID: 69 unique values
# FolderType: 2 unique values
# YearFolder: 4 unique values
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 88
#      79     print(f"{col}: {unique_count} unique values")
#      81 # %% [markdown]
#      82 # ## Identify Rows with Problematic Values
#      83 #
#    (...)     86 # %%
#      87 # Identify rows with any NaN or infinite values
# ---> 88 problematic_rows = df[df.isnull().any(axis=1) | df.apply(lambda x: np.isinf(x)).any(axis=1)]
#      89 print("\n--- Rows with Missing or Infinite Values ---")
#      90 print(problematic_rows)
#
# File ~/Desktop/codes/clustering/clustering_env/lib/python3.12/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)  10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/Desktop/codes/clustering/clustering_env/lib/python3.12/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/Desktop/codes/clustering/clustering_env/lib/python3.12/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/Desktop/codes/clustering/clustering_env/lib/python3.12/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[2], line 88, in <lambda>(x)
#      79     print(f"{col}: {unique_count} unique values")
#      81 # %% [markdown]
#      82 # ## Identify Rows with Problematic Values
#      83 #
#    (...)     86 # %%
#      87 # Identify rows with any NaN or infinite values
# ---> 88 problematic_rows = df[df.isnull().any(axis=1) | df.apply(lambda x: np.isinf(x)).any(axis=1)]
#      89 print("\n--- Rows with Missing or Infinite Values ---")
#      90 print(problematic_rows)
#
# File ~/Desktop/codes/clustering/clustering_env/lib/python3.12/site-packages/pandas/core/generic.py:2171, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2167 @final
#    2168 def __array_ufunc__(
#    2169     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2170 ):
# -> 2171     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File ~/Desktop/codes/clustering/clustering_env/lib/python3.12/site-packages/pandas/core/arraylike.py:399, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     396 elif self.ndim == 1:
#     397     # ufunc(series, ...)
#     398     inputs = tuple(extract_array(x, extract_numpy=True) for x in inputs)
# --> 399     result = getattr(ufunc, method)(*inputs, **kwargs)
#     400 else:
#     401     # ufunc(dataframe)
#     402     if method == "__call__" and not kwargs:
#     403         # for np.<ufunc>(..) calls
#     404         # kwargs cannot necessarily be handled block-by-block, so only
#     405         # take this path if there are no kwargs
#
# TypeError: ufunc 'isinf' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
