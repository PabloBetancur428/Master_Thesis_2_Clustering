# %% [markdown]
# # Lesion analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from save_explore_dataframe import save_and_explore_dataframe

# %% [markdown]
# # Analyzing all data

# %%
all_lesions = pd.read_csv("/home/jbetancur/Desktop/codes/clustering/lesion_exploration/output/rawlesion_volumes.csv")
all_lesions.shape
# Out:
# (3766, 5)

# %%
save_and_explore_dataframe(all_lesions, output_dir="lesion_exploration/output", filename_prefix="original" )
# Out:
# DataFrame saved to lesion_exploration/output/originallesion_volumes.csv
# Summary Statistics:
#  count      3766.000000
# mean        261.502029
# std        6652.953415
# min           0.999983
# 25%           4.002844
# 50%          16.003643
# 75%          66.997365
# max      399072.574196
# Name: LesionVolume, dtype: float64
# Comprehensive plot saved to lesion_exploration/output/originallesion_volume_distribution_comprehensive_all.png
# Skewness: 57.6877120360072
# Kurtosis: 3437.2473800560438
# Number of outlier lesions: 527
# Outliers:
#        PatientID FolderType YearFolder  LesionLabel  LesionVolume
# 39     16884118   baseline       2023            2   1468.115252
# 53     16884118   baseline       2023           16    316.024809
# 54     16884118   baseline       2023           17    204.016016
# 56     16884118   baseline       2023           19    637.050011
# 61     16884118   baseline       2023           24    182.014289
# ...

# %% [markdown]
# ### Lesion Volume < 10000

# %%
# FIltered dataframe below 10000 volume
filtered_df = all_lesions[all_lesions['LesionVolume'] < 10000]
save_and_explore_dataframe(filtered_df, filename_prefix="less10000")
# Out:
# DataFrame saved to ./output/less10000lesion_volumes.csv
# Summary Statistics:
#  count    3761.000000
# mean      125.628971
# std       512.511594
# min         0.999983
# 25%         4.002844
# 50%        16.001206
# 75%        66.015688
# max      9098.068135
# Name: LesionVolume, dtype: float64
# Comprehensive plot saved to ./output/less10000lesion_volume_distribution_comprehensive_all.png
# Skewness: 10.769420838126045
# Kurtosis: 143.36272250628977
# Number of outlier lesions: 528
# Outliers:
#        PatientID FolderType YearFolder  LesionLabel  LesionVolume
# 39     16884118   baseline       2023            2   1468.115252
# 53     16884118   baseline       2023           16    316.024809
# 54     16884118   baseline       2023           17    204.016016
# 56     16884118   baseline       2023           19    637.050011
# 61     16884118   baseline       2023           24    182.014289
# ...         ...        ...        ...          ...           ...
# ...

# %% [markdown]
# ### Lesion Volume < 2000

# %%
# Filtered dataframe below 2000 volume
filtered_df = all_lesions[all_lesions['LesionVolume'] < 2000]
save_and_explore_dataframe(filtered_df, filename_prefix="less2000")
# Out:
# DataFrame saved to ./output/less2000lesion_volumes.csv
# Summary Statistics:
#  count    3724.000000
# mean       83.527906
# std       196.115998
# min         0.999983
# 25%         4.002844
# 50%        16.000037
# 75%        62.999723
# max      1990.150885
# Name: LesionVolume, dtype: float64
# Comprehensive plot saved to ./output/less2000lesion_volume_distribution_comprehensive_all.png
# Skewness: 4.818220988022137
# Kurtosis: 29.122968055442982
# Number of outlier lesions: 506
# Outliers:
#        PatientID FolderType YearFolder  LesionLabel  LesionVolume
# 39     16884118   baseline       2023            2   1468.115252
# 53     16884118   baseline       2023           16    316.024809
# 54     16884118   baseline       2023           17    204.016016
# 56     16884118   baseline       2023           19    637.050011
# 61     16884118   baseline       2023           24    182.014289
# ...         ...        ...        ...          ...           ...
# ...

# %% [markdown]
# ### Lesion Volume < 500

# %%
filtered_df = all_lesions[all_lesions['LesionVolume'] < 500]
save_and_explore_dataframe(filtered_df, filename_prefix="less500")
# Out:
# DataFrame saved to ./output/less500lesion_volumes.csv
# Summary Statistics:
#  count    3586.000000
# mean       51.764771
# std        86.606719
# min         0.999983
# 25%         4.001497
# 50%        13.005189
# 75%        53.758724
# max       495.978038
# Name: LesionVolume, dtype: float64
# Comprehensive plot saved to ./output/less500lesion_volume_distribution_comprehensive_all.png
# Skewness: 2.6743863359386344
# Kurtosis: 7.344310441508865
# Number of outlier lesions: 434
# Outliers:
#        PatientID FolderType YearFolder  LesionLabel  LesionVolume
# 38     16884118   baseline       2023            1    151.011855
# 48     16884118   baseline       2023           11    143.011227
# 53     16884118   baseline       2023           16    316.024809
# 54     16884118   baseline       2023           17    204.016016
# 61     16884118   baseline       2023           24    182.014289
# ...         ...        ...        ...          ...           ...
# ...

# %% [markdown]
# ### Lesion Volume < 250

# %%
filtered_df = all_lesions[all_lesions['LesionVolume'] < 250]
save_and_explore_dataframe(filtered_df, filename_prefix="less250")
# Out:
# DataFrame saved to ./output/less250lesion_volumes.csv
# Summary Statistics:
#  count    3397.000000
# mean       35.337231
# std        50.222603
# min         0.999983
# 25%         4.000303
# 50%        12.000234
# 75%        42.015719
# max       249.836253
# Name: LesionVolume, dtype: float64
# Comprehensive plot saved to ./output/less250lesion_volume_distribution_comprehensive_all.png
# Skewness: 2.190018463602362
# Kurtosis: 4.482123954997096
# Number of outlier lesions: 366
# Outliers:
#        PatientID FolderType YearFolder  LesionLabel  LesionVolume
# 7      14109676   baseline       2022            8    127.993153
# 28     16414583   baseline       2023            8    118.073750
# 32     16414583   baseline       2023           12     99.061875
# 38     16884118   baseline       2023            1    151.011855
# 48     16884118   baseline       2023           11    143.011227
# ...         ...        ...        ...          ...           ...
# ...

# %% [markdown]
# ### Lesion Volume < 100

# %%
filtered_df = all_lesions[all_lesions['LesionVolume'] < 100]
save_and_explore_dataframe(filtered_df, filename_prefix="less100")
# Out:
# DataFrame saved to ./output/less100lesion_volumes.csv
# Summary Statistics:
#  count    3033.000000
# mean       20.416957
# std        22.885023
# min         0.999983
# 25%         4.000095
# 50%        10.007111
# 75%        27.999533
# max        99.986297
# Name: LesionVolume, dtype: float64
# Comprehensive plot saved to ./output/less100lesion_volume_distribution_comprehensive_all.png
# Skewness: 1.5965848010752484
# Kurtosis: 1.7488516095178297
# Number of outlier lesions: 233
# Outliers:
#        PatientID FolderType YearFolder  LesionLabel  LesionVolume
# 32     16414583   baseline       2023           12     99.061875
# 57     16884118   baseline       2023           20     96.007537
# 65     10844214   baseline       2023            3     88.994036
# 68     10844214   baseline       2023            6     90.993902
# 92     10844214   baseline       2023           30     95.993566
# ...         ...        ...        ...          ...           ...
# ...

# %% [markdown]
# # Analyzing outlier distributions

# %%
lesions_raw = pd.read_csv("/home/jbetancur/Desktop/codes/clustering/lesion_exploration/output/rawlesion_outliers_all.csv")

# %%
save_and_explore_dataframe(lesions_raw, output_dir="lesion_exploration/output", filename_prefix="raw_outliers_")
# Out:
# DataFrame saved to lesion_exploration/output/raw_outliers_lesion_volumes.csv
# Summary Statistics:
#  count       527.000000
# mean       1701.688235
# std       17731.140023
# min         162.012283
# 25%         234.514000
# 50%         349.003749
# 75%         680.499350
# max      399072.574196
# Name: LesionVolume, dtype: float64
# Comprehensive plot saved to lesion_exploration/output/raw_outliers_lesion_volume_distribution_comprehensive_all.png
# Skewness: 21.638369572147703
# Kurtosis: 482.74019206754906
# Number of outlier lesions: 63
# Outliers:
#       PatientID FolderType YearFolder  LesionLabel   LesionVolume
# 0     16884118   baseline       2023            2    1468.115252
# 19    11638211   baseline       2022           34    1624.122411
# 41    12014187   baseline       2023           17    7555.048290
# 55    12624080   baseline       2023           13    3142.878475
# 72    11721892   baseline       2023            4    3412.912380
# ...

# %%
outliers_lesions_500 = pd.read_csv("/home/jbetancur/Desktop/codes/clustering/lesion_exploration/output/less500lesion_outliers_all.csv")
save_and_explore_dataframe(outliers_lesions_500, filename_prefix="outliers500_")
# Out:
# DataFrame saved to ./output/outliers500_lesion_volumes.csv
# Summary Statistics:
#  count    434.000000
# mean     253.809652
# std       97.755725
# min      128.998871
# 25%      173.998572
# 50%      232.513503
# 75%      321.984471
# max      495.978038
# Name: LesionVolume, dtype: float64
# Comprehensive plot saved to ./output/outliers500_lesion_volume_distribution_comprehensive_all.png
# Skewness: 0.7249908053013987
# Kurtosis: -0.4604746784658036
# Number of outlier lesions: 0
# Outliers:
#  Empty DataFrame
# Columns: [PatientID, FolderType, YearFolder, LesionLabel, LesionVolume]
# Index: []
#      PatientID FolderType YearFolder  LesionLabel  LesionVolume
# 0     16884118   baseline       2023            1    151.011855
# 1     16884118   baseline       2023           11    143.011227
# 2     16884118   baseline       2023           16    316.024809
# 3     16884118   baseline       2023           17    204.016016
# ...
